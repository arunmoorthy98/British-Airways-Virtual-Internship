# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data= '/customer_booking.csv'

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
print(os.listdir())
# Out:
# ['.config', 'customer_booking.csv', 'sample_data']

# %%
import chardet

with open('customer_booking.csv', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
# Load the dataset with the detected encoding
encoding = result['encoding']
data = pd.read_csv('customer_booking.csv', encoding=encoding)

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
data.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2      Internet  RoundTrip            262              19
# 1               1      Internet  RoundTrip            112              20
# 2               2      Internet  RoundTrip            243              22
# 3               1      Internet  RoundTrip             96              31
# 4               2      Internet  RoundTrip             68              22
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            7        Sat  AKLDEL    New Zealand                    1
# 1            3        Sat  AKLDEL    New Zealand                    0
# 2           17        Wed  AKLDEL          India                    1
# 3            4        Sat  AKLDEL    New Zealand                    0
# 4           15        Wed  AKLDEL          India                    1
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# 0                     0                      0             5.52
# 1                     0                      0             5.52
# 2                     1                      0             5.52
# 3                     0                      1             5.52
# 4                     0                      1             5.52
#
#    booking_complete
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
data.dtypes
# Out:
# num_passengers             int64
# sales_channel             object
# trip_type                 object
# purchase_lead              int64
# length_of_stay             int64
# flight_hour                int64
# flight_day                object
# route                     object
# booking_origin            object
# wants_extra_baggage        int64
# wants_preferred_seat       int64
# wants_in_flight_meals      int64
# flight_duration          float64
# booking_complete           int64
# dtype: object

# %%
data.shape
# Out:
# (50000, 14)

# %%
#null values

data.isnull().sum()

#there is no null values
# Out:
# num_passengers           0
# sales_channel            0
# trip_type                0
# purchase_lead            0
# length_of_stay           0
# flight_hour              0
# flight_day               0
# route                    0
# booking_origin           0
# wants_extra_baggage      0
# wants_preferred_seat     0
# wants_in_flight_meals    0
# flight_duration          0
# booking_complete         0
# dtype: int64

# %%
data.booking_complete.value_counts()
# Out:
# booking_complete
# 0    42522
# 1     7478
# Name: count, dtype: int64

# %% [markdown]
# # **Mutual Information**

# %%
X = data.drop('booking_complete', axis=1)
y = data['booking_complete']

# Changing object dtype to int dtype
for colname in X.select_dtypes("object"):
    X[colname], _ = X[colname].factorize()

# Checking data types after conversion
print(X.dtypes)
# Out:
# num_passengers             int64
# sales_channel              int64
# trip_type                  int64
# purchase_lead              int64
# length_of_stay             int64
# flight_hour                int64
# flight_day                 int64
# route                      int64
# booking_origin             int64
# wants_extra_baggage        int64
# wants_preferred_seat       int64
# wants_in_flight_meals      int64
# flight_duration          float64
# dtype: object

# %%
from sklearn.feature_selection import mutual_info_classif

mi_scores = mutual_info_classif(X, y)
mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
mi_scores = mi_scores.sort_values(ascending=False)

mi_scores # show a few features with their MI scores
# Out:
# route                    0.052512
# booking_origin           0.047826
# flight_duration          0.019280
# wants_extra_baggage      0.010499
# length_of_stay           0.005917
# wants_in_flight_meals    0.005640
# wants_preferred_seat     0.003623
# flight_day               0.002974
# num_passengers           0.002243
# sales_channel            0.000000
# trip_type                0.000000
# purchase_lead            0.000000
# flight_hour              0.000000
# Name: MI Scores, dtype: float64

# %%
import matplotlib.pyplot as plt

def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)

    plt.figure(figsize=(10, 6))
    plt.bar(width, scores)
    plt.xticks(width, ticks, rotation=90)
    plt.title("Mutual Information Scores")
    plt.xlabel('Features')
    plt.ylabel('Mutual Information Score')
    plt.tight_layout()

# Example usage:
# Assuming mi_scores is your mutual information scores Series or DataFrame
plot_mi_scores(mi_scores)
plt.show()

# %%
# Example pairplot
sns.pairplot(data=data, vars=['flight_hour', 'flight_duration', 'length_of_stay', 'num_passengers'], hue='sales_channel', palette='husl')
plt.suptitle('Pairplot of Flight Hour, Flight Duration, Length of Stay, and Num Passengers')
plt.show()

# %%
#test train split

from sklearn.model_selection import train_test_split

# dataset split
# creating a function for dataset split
def dataset(X,y):
    train_full_X, val_X, train_full_y, val_y = train_test_split(X, y,test_size=0.2,random_state = 0)

# Use the same function above for the validation set
    train_X, test_X, train_y, test_y = train_test_split(train_full_X, train_full_y, test_size=0.25,random_state = 0)
    return (train_X, val_X, train_y, val_y)

# %%
from sklearn.preprocessing import MinMaxScaler

def scale(X):
    scaler = MinMaxScaler()
    scaler.fit(X)
    return X

# %% [markdown]
# # **Model 1 : Random forest classifier with top 6 features**

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier



#assigning the features under a list

features=['route','booking_origin','flight_duration','wants_extra_baggage', 'length_of_stay','num_passengers']
X= data[features]
#one hot encoding
X = pd.get_dummies(X, columns=features)
X= scale(X)
y= data.booking_complete

X_train,X_val,y_train,y_val= dataset(X,y)

forest_model= RandomForestClassifier(random_state=1)
forest_model.fit(X_train, y_train)
preds= forest_model.predict(X_val)

print('ACCURACY: ',accuracy_score(y_val,preds)*100)
print('AUC score: ',roc_auc_score(y_val,preds))
# Out:
# ACCURACY:  83.36
# AUC score:  0.5657818407546988

# %% [markdown]
# # **Model 2 : Random forest classifier with all features**

# %%
X= data.drop('booking_complete',axis=1)
#one hot encoding
X = pd.get_dummies(X)
X= scale(X)
y= data.booking_complete

X_train,X_val,y_train,y_val= dataset(X,y)

forest_model= RandomForestClassifier(random_state=1)
forest_model.fit(X_train, y_train)
preds= forest_model.predict(X_val)

print('ACCURACY: ',accuracy_score(y_val,preds)*100)
print('AUC score: ',roc_auc_score(y_val,preds))
# Out:
# ACCURACY:  84.76
# AUC score:  0.5479604084813514

# %% [markdown]
# # #**Model 3 : XGB classifier with top 6 features**

# %%
from xgboost import XGBClassifier

X= data[features]

#one hot encoding
X = pd.get_dummies(X, columns=features)
X= scale(X)

y= data.booking_complete

X_train,X_val,y_train,y_val= dataset(X,y)
xgb_model = XGBClassifier()

xgb_model.fit(X_train, y_train)
prediction_xgb = xgb_model.predict(X_val)
print('ACCURACY: ',accuracy_score(y_val, prediction_xgb)*100)
print('AUC score: ',roc_auc_score(y_val,prediction_xgb))
# Out:
# ACCURACY:  84.72
# AUC score:  0.5189398567740671

# %% [markdown]
# # **Model 4 : XGB classifier with all features**

# %%
X= data.drop('booking_complete',axis=1)
#one hot encoding
X = pd.get_dummies(X)
X= scale(X)
y= data.booking_complete

X_train,X_val,y_train,y_val= dataset(X,y)


xgb_model = XGBClassifier()
xgb_model.fit(X_train, y_train)
prediction_xgb = xgb_model.predict(X_val)
print('ACCURACY: ',accuracy_score(y_val, prediction_xgb)*100)
print('AUC score: ',roc_auc_score(y_val,prediction_xgb))
# Out:
# ACCURACY:  84.98
# AUC score:  0.5424676175552812

# %% [markdown]
# Finalizing random forest model with all features as final model, as it has goos accuracy and higher auc score compared to other models
#
# Validating with test data set

# %%
X= data.drop('booking_complete',axis=1)
#one hot encoding
X = pd.get_dummies(X)
X= scale(X)
y= data.booking_complete

train_full_X,test_X, train_full_y, test_y = train_test_split(X, y,test_size=0.2,random_state = 0)

forest_model= RandomForestClassifier(random_state=1)
forest_model.fit(train_full_X, train_full_y)
preds= forest_model.predict(test_X)

print('ACCURACY: ',accuracy_score(test_y,preds)*100)
print('AUC score: ',roc_auc_score(test_y,preds))
# Out:
# ACCURACY:  85.09
# AUC score:  0.5577796717361984
